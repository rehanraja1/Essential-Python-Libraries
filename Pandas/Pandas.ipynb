# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data=[10,20,30,40,50]
data2=[10.0,20,30,40,50]
s1=pd.Series(data)
s2=pd.Series(data2)
print(s1)
print(s2)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# 0    10.0
# 1    20.0
# 2    30.0
# 3    40.0
# 4    50.0
# dtype: float64

# %%
print(type(s1))
print(type(s2))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
s1.values #gives nd array
# Out:
# array([10, 20, 30, 40, 50])

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
 s1.dtype
# Out:
# dtype('int64')

# %%
data2=["10",20,30]
s2=pd.Series(data2) #gives object because str cant be converted into int
s2.dtype
# Out:
# dtype('O')

# %%
s1.index=[101,102,103,104,105]
s1
# Out:
# 101    10
# 102    20
# 103    30
# 104    40
# 105    50
# dtype: int64

# %%
s1.index=range(101,106)
s1
# Out:
# 101    10
# 102    20
# 103    30
# 104    40
# 105    50
# dtype: int64

# %%
s1.index=[1.5,1.6,1.7,2.1,3.1]
s1
# Out:
# 1.5    10
# 1.6    20
# 1.7    30
# 2.1    40
# 3.1    50
# dtype: int64

# %%
s1.index=['A','b','c','d','e']
s1
# Out:
# A    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
s1.index
# Out:
# Index(['A', 'b', 'c', 'd', 'e'], dtype='object')

# %% [markdown]
# **Accessing data in series**

# %%
print(s1[0])
print(s1[-1])
print(s1['A'])
print(s1['d'])
# Out:
# 10
# 50
# 10
# 40

# %%
#Accessing Using iloc
print(s1.iloc[0] ,end='\n \n')
s1.iloc[[2,1,3]]
# Out:
# 10
# c    30
# b    20
# d    40
# dtype: int64

# %%
#Accessing using loc
print(s1.loc['A'])
s1.loc[['A','c','e']]
# Out:
# 10
# A    10
# c    30
# e    50
# dtype: int64

# %%
print(s1.loc[list(s1.index)])
# Out:
# A    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %% [markdown]
# **ADD Udpade And Delete Operations**

# %%
#add
s1['F']=100
s1
# Out:
# A     10
# b     20
# c     30
# d     40
# e     50
# F    100
# dtype: int64

# %%
#update
s1['A']=11
s1
# Out:
# A     11
# b     20
# c     30
# d     40
# e     50
# F    100
# dtype: int64

# %%
#Delete
s1.drop('d',inplace=True)

# %%
s1
# Out:
# A     11
# b     20
# c     30
# e     50
# F    100
# dtype: int64

# %% [markdown]
# **Slicing**

# %%
print(s1[:],end='\n')
print(s1[2:5], end='\n')
print(s1[-1::-1])
print(s1[::2])
# Out:
# A     11
# b     20
# c     30
# e     50
# F    100
# dtype: int64
# c     30
# e     50
# F    100
# dtype: int64
# F    100
# e     50
# c     30
# b     20
# A     11
# dtype: int64
# A     11
# c     30
# F    100
# dtype: int64

# %% [markdown]
# **Creating Series From Dictionary**

# %%
dictdata={'Kabir': 88, 'Meera': 74, 'Riya': 91, 'Arjun': 67, 'Zara': 59, 'Ayaan': 83, 'Rahul': 72}
s=pd.Series(dictdata)
s
# Out:
# Kabir    88
# Meera    74
# Riya     91
# Arjun    67
# Zara     59
# Ayaan    83
# Rahul    72
# dtype: int64

# %%
states_capitals = {
    "Karnataka": "Bengaluru",
    "Maharashtra": "Mumbai",
    "Tamil Nadu": "Chennai",
    "Kerala": "Thiruvananthapuram",
    "Rajasthan": "Jaipur",
    "Gujarat": "Gandhinagar",
    "West Bengal": "Kolkata",
    "Punjab": "Chandigarh",
    "Haryana": "Chandigarh",
    "Uttar Pradesh": "Lucknow",
    "Madhya Pradesh": "Bhopal",
    "Bihar": "Patna",
    "Odisha": "Bhubaneswar"
}
s2=pd.Series(states_capitals)
s2
# Out:
# Karnataka                  Bengaluru
# Maharashtra                   Mumbai
# Tamil Nadu                   Chennai
# Kerala            Thiruvananthapuram
# Rajasthan                     Jaipur
# Gujarat                  Gandhinagar
# West Bengal                  Kolkata
# Punjab                    Chandigarh
# Haryana                   Chandigarh
# Uttar Pradesh                Lucknow
# Madhya Pradesh                Bhopal
# Bihar                          Patna
# Odisha                   Bhubaneswar
# dtype: object

# %%
#Accessing elements
print(s['Zara'])
print(s2['Punjab'])
print(s[0])
print(s2[0])
# Out:
# 59
# Chandigarh
# 88
# Bengaluru

# %%
print(s1.index, end='\n \n')
print(s2.index)
# Out:
# Index(['A', 'b', 'c', 'e', 'F'], dtype='object')
#
# Index(['Karnataka', 'Maharashtra', 'Tamil Nadu', 'Kerala', 'Rajasthan',
#        'Gujarat', 'West Bengal', 'Punjab', 'Haryana', 'Uttar Pradesh',
#        'Madhya Pradesh', 'Bihar', 'Odisha'],
#       dtype='object')

# %%
print(s.values, end='\n \n')
print(s2.values)
# Out:
# [88 74 91 67 59 83 72]
#
# ['Bengaluru' 'Mumbai' 'Chennai' 'Thiruvananthapuram' 'Jaipur'
#  'Gandhinagar' 'Kolkata' 'Chandigarh' 'Chandigarh' 'Lucknow' 'Bhopal'
#  'Patna' 'Bhubaneswar']

# %%
s2.loc['Bihar']
# Out:
# 'Patna'

# %%
s2.loc[list(s2.index)]
# Out:
# Karnataka                  Bengaluru
# Maharashtra                   Mumbai
# Tamil Nadu                   Chennai
# Kerala            Thiruvananthapuram
# Rajasthan                     Jaipur
# Gujarat                  Gandhinagar
# West Bengal                  Kolkata
# Punjab                    Chandigarh
# Haryana                   Chandigarh
# Uttar Pradesh                Lucknow
# Madhya Pradesh                Bhopal
# Bihar                          Patna
# Odisha                   Bhubaneswar
# dtype: object

# %%
print(s2.iloc[0])
print(s2.iloc[1])
s2.iloc[[1,3,5]]
# Out:
# Bengaluru
# Mumbai
# Maharashtra                Mumbai
# Kerala         Thiruvananthapuram
# Gujarat               Gandhinagar
# dtype: object

# %%
#we can name the series
s2.name="States And Capitals"
s2
# Out:
# Karnataka                  Bengaluru
# Maharashtra                   Mumbai
# Tamil Nadu                   Chennai
# Kerala            Thiruvananthapuram
# Rajasthan                     Jaipur
# Gujarat                  Gandhinagar
# West Bengal                  Kolkata
# Punjab                    Chandigarh
# Haryana                   Chandigarh
# Uttar Pradesh                Lucknow
# Madhya Pradesh                Bhopal
# Bihar                          Patna
# Odisha                   Bhubaneswar
# Name: States And Capitals, dtype: object

# %%
s2.index.name="States"
s2
# Out:
# States
# Karnataka                  Bengaluru
# Maharashtra                   Mumbai
# Tamil Nadu                   Chennai
# Kerala            Thiruvananthapuram
# Rajasthan                     Jaipur
# Gujarat                  Gandhinagar
# West Bengal                  Kolkata
# Punjab                    Chandigarh
# Haryana                   Chandigarh
# Uttar Pradesh                Lucknow
# Madhya Pradesh                Bhopal
# Bihar                          Patna
# Odisha                   Bhubaneswar
# Name: States And Capitals, dtype: object

# %%
print(s2.index ,end='\n \n')
print(s2.values ,end='\n \n')
print(s2.name ,end='\n \n')
print(s2.index.name ,end='\n \n')
print(s2.dtype)
# Out:
# Index(['Karnataka', 'Maharashtra', 'Tamil Nadu', 'Kerala', 'Rajasthan',
#        'Gujarat', 'West Bengal', 'Punjab', 'Haryana', 'Uttar Pradesh',
#        'Madhya Pradesh', 'Bihar', 'Odisha'],
#       dtype='object', name='States')
#
# ['Bengaluru' 'Mumbai' 'Chennai' 'Thiruvananthapuram' 'Jaipur'
#  'Gandhinagar' 'Kolkata' 'Chandigarh' 'Chandigarh' 'Lucknow' 'Bhopal'
#  'Patna' 'Bhubaneswar']
#
# States And Capitals
#
# States
#
# object

# %%
rollno=[101,102,103]
marks=[99,88,98]
s=pd.Series(data=marks,index=rollno)
s.name="Final Marks"
s.index.name="Roll Number"
print(s)
# Out:
# Roll Number
# 101    99
# 102    88
# 103    98
# Name: Final Marks, dtype: int64

# %%
states=["Karnataka", "Maharashtra", "Tamil Nadu","Telangana", "Assam"]
s3=pd.Series(data=s2,index=states)
s3
# Out:
# Karnataka      Bengaluru
# Maharashtra       Mumbai
# Tamil Nadu       Chennai
# Telangana            NaN
# Assam                NaN
# Name: States And Capitals, dtype: object

# %% [markdown]
# **Functios**

# %%
s4=s3.isnull()
s4
# Out:
# Karnataka      False
# Maharashtra    False
# Tamil Nadu     False
# Telangana       True
# Assam           True
# Name: States And Capitals, dtype: bool

# %%
s3.notnull()
# Out:
# Karnataka       True
# Maharashtra     True
# Tamil Nadu      True
# Telangana      False
# Assam          False
# Name: States And Capitals, dtype: bool

# %%
print(s3.isnull().sum())
print(s3.notnull().sum())
# Out:
# 2
# 3

# %%
print(s3.head() , end='\n \n')
print(s3.head(2))
# Out:
# Karnataka      Bengaluru
# Maharashtra       Mumbai
# Tamil Nadu       Chennai
# Telangana            NaN
# Assam                NaN
# Name: States And Capitals, dtype: object
#
# Karnataka      Bengaluru
# Maharashtra       Mumbai
# Name: States And Capitals, dtype: object

# %%
print(s3.tail() , end='\n \n')
print(s3.tail(2))
# Out:
# Karnataka      Bengaluru
# Maharashtra       Mumbai
# Tamil Nadu       Chennai
# Telangana            NaN
# Assam                NaN
# Name: States And Capitals, dtype: object
#
# Telangana    NaN
# Assam        NaN
# Name: States And Capitals, dtype: object

# %%
s3.index=range(111,116)

# %%
s3
# Out:
# 111    Bengaluru
# 112       Mumbai
# 113      Chennai
# 114          NaN
# 115          NaN
# Name: States And Capitals, dtype: object

# %%
s3[117]="Pune"
s3[118]="Pune"
s3[119]="Pune"
s3
# Out:
# 111    Bengaluru
# 112       Mumbai
# 113      Chennai
# 114          NaN
# 115          NaN
# 117         Pune
# 118         Pune
# 119         Pune
# Name: States And Capitals, dtype: object

# %%
s3.dropna(inplace=True)
s3
# Out:
# 111    Bengaluru
# 112       Mumbai
# 113      Chennai
# 117         Pune
# 118         Pune
# 119         Pune
# Name: States And Capitals, dtype: object

# %%
s3.duplicated()
# Out:
# 111    False
# 112    False
# 113    False
# 117    False
# 118     True
# 119     True
# Name: States And Capitals, dtype: bool

# %%
s3.duplicated().sum()
# Out:
# np.int64(2)

# %%
s3.dropna().duplicated().sum()
# Out:
# np.int64(2)

# %%
s3.drop_duplicates(inplace=True)
s3
# Out:
# 111    Bengaluru
# 112       Mumbai
# 113      Chennai
# 117         Pune
# Name: States And Capitals, dtype: object

# %% [markdown]
# **DataFrames**

# %%
emp1 = pd.Series({'Name': 'Rahul', 'ID': 201, 'Gender': 'Male', 'Salary': 50000})
emp2 = pd.Series({'Name': 'Anita', 'ID': 202, 'Gender': 'Female', 'Salary': 55000})
emp3 = pd.Series({'Name': 'Vikram', 'ID': 203, 'Gender': 'Male', 'Salary': 60000})
emp4 = pd.Series({'Name': 'Sneha', 'ID': 204, 'Gender': 'Female', 'Salary': 52000})
emp5 = pd.Series({'Name': 'Arjun', 'ID': 205, 'Gender': 'Male', 'Salary': 58000})
emp6 = pd.Series({'Name': 'Priya', 'ID': 206, 'Gender': 'Female', 'Salary': 61000})
emp7 = pd.Series({'Name': 'Karan', 'ID': 207, 'Gender': 'Male', 'Salary': 53000})
emp8 = pd.Series({'Name': 'Meera', 'ID': 208, 'Gender': 'Female', 'Salary': 59000})
emp9 = pd.Series({'Name': 'Rohit', 'ID': 209, 'Gender': 'Male', 'Salary': 62000})
emp10 = pd.Series({'Name': 'Divya', 'ID': 210, 'Gender': 'Female', 'Salary': 54000})
emp11 = pd.Series({'Name': 'Aman', 'ID': 211, 'Gender': 'Male', 'Salary': 57000})
emp12 = pd.Series({'Name': 'Neha', 'ID': 212, 'Gender': 'Female', 'Salary': 63000})

# %%
emp3
# Out:
# Name      Vikram
# ID           203
# Gender      Male
# Salary     60000
# dtype: object

# %%
employees=[emp1,emp2,emp3,emp4,emp5,emp6,emp7,emp8,emp9,emp10,emp11,emp12]
df1=pd.DataFrame(data=employees,index=range(101,113))
df1
# Out:
#        Name   ID  Gender  Salary
# 101   Rahul  201    Male   50000
# 102   Anita  202  Female   55000
# 103  Vikram  203    Male   60000
# 104   Sneha  204  Female   52000
# 105   Arjun  205    Male   58000
# 106   Priya  206  Female   61000
# 107   Karan  207    Male   53000
# 108   Meera  208  Female   59000
# 109   Rohit  209    Male   62000
# 110   Divya  210  Female   54000
# 111    Aman  211    Male   57000
# 112    Neha  212  Female   63000

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
print(df1.head() ,end='\n \n')
print(df1.head(2))
# Out:
#        Name   ID  Gender  Salary
# 101   Rahul  201    Male   50000
# 102   Anita  202  Female   55000
# 103  Vikram  203    Male   60000
# 104   Sneha  204  Female   52000
# 105   Arjun  205    Male   58000
#
#       Name   ID  Gender  Salary
# 101  Rahul  201    Male   50000
# 102  Anita  202  Female   55000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 101 to 112
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    12 non-null     object
#  1   ID      12 non-null     int64
#  2   Gender  12 non-null     object
#  3   Salary  12 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 516.0+ bytes

# %%
list(df1.index)
# Out:
# [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112]

# %%
df1.columns
# Out:
# Index(['Name', 'ID', 'Gender', 'Salary'], dtype='object')

# %%
df1.values
# Out:
# array([['Rahul', 201, 'Male', 50000],
#        ['Anita', 202, 'Female', 55000],
#        ['Vikram', 203, 'Male', 60000],
#        ['Sneha', 204, 'Female', 52000],
#        ['Arjun', 205, 'Male', 58000],
#        ['Priya', 206, 'Female', 61000],
#        ['Karan', 207, 'Male', 53000],
#        ['Meera', 208, 'Female', 59000],
#        ['Rohit', 209, 'Male', 62000],
#        ['Divya', 210, 'Female', 54000],
#        ['Aman', 211, 'Male', 57000],
#        ['Neha', 212, 'Female', 63000]], dtype=object)

# %%
df1.name='Employee_Details'
df1.index.name='Employee_ID'
#df1.columns.name='Employee_Details'
df1
# Out:
#                Name   ID  Gender  Salary
# Employee_ID
# 101           Rahul  201    Male   50000
# 102           Anita  202  Female   55000
# 103          Vikram  203    Male   60000
# 104           Sneha  204  Female   52000
# 105           Arjun  205    Male   58000
# 106           Priya  206  Female   61000
# 107           Karan  207    Male   53000
# 108           Meera  208  Female   59000
# 109           Rohit  209    Male   62000
# 110           Divya  210  Female   54000
# 111            Aman  211    Male   57000
# 112            Neha  212  Female   63000

# %%
print(df1.name)
print(df1.index.name)
# Out:
# Employee_Details
# Employee_ID

# %%
df1.describe()
# Out:
#                ID        Salary
# count   12.000000     12.000000
# mean   206.500000  57000.000000
# std      3.605551   4199.567077
# min    201.000000  50000.000000
# 25%    203.750000  53750.000000
# 50%    206.500000  57500.000000
# 75%    209.250000  60250.000000
# max    212.000000  63000.000000

# %% [markdown]
# **Accessing Data From DataFrame**

# %%
df1
# Out:
#                Name   ID  Gender  Salary
# Employee_ID
# 101           Rahul  201    Male   50000
# 102           Anita  202  Female   55000
# 103          Vikram  203    Male   60000
# 104           Sneha  204  Female   52000
# 105           Arjun  205    Male   58000
# 106           Priya  206  Female   61000
# 107           Karan  207    Male   53000
# 108           Meera  208  Female   59000
# 109           Rohit  209    Male   62000
# 110           Divya  210  Female   54000
# 111            Aman  211    Male   57000
# 112            Neha  212  Female   63000

# %% [markdown]
# **Accessing Columns**

# %%
type(df1['Name'])
# Out:
# pandas.core.series.Series

# %%
print(df1['Name'],end='\n \n')
print(df1[['Name','Salary']])
# Out:
# Employee_ID
# 101     Rahul
# 102     Anita
# 103    Vikram
# 104     Sneha
# 105     Arjun
# 106     Priya
# 107     Karan
# 108     Meera
# 109     Rohit
# 110     Divya
# 111      Aman
# 112      Neha
# Name: Name, dtype: object
#
#                Name  Salary
# Employee_ID
# 101           Rahul   50000
# 102           Anita   55000
# 103          Vikram   60000
# 104           Sneha   52000
# 105           Arjun   58000
# 106           Priya   61000
# 107           Karan   53000
# 108           Meera   59000
# 109           Rohit   62000
# 110           Divya   54000
# 111            Aman   57000
# 112            Neha   63000

# %%
print(df1.Name,end='\n \n')
print(df1.Salary)
# Out:
# Employee_ID
# 101     Rahul
# 102     Anita
# 103    Vikram
# 104     Sneha
# 105     Arjun
# 106     Priya
# 107     Karan
# 108     Meera
# 109     Rohit
# 110     Divya
# 111      Aman
# 112      Neha
# Name: Name, dtype: object
#
# Employee_ID
# 101    50000
# 102    55000
# 103    60000
# 104    52000
# 105    58000
# 106    61000
# 107    53000
# 108    59000
# 109    62000
# 110    54000
# 111    57000
# 112    63000
# Name: Salary, dtype: int64

# %% [markdown]
# **Accessing Rows**

# %%
df1.loc[101] #Custom Index
# Out:
# Name      Rahul
# ID          201
# Gender     Male
# Salary    50000
# Name: 101, dtype: object

# %%
df1.loc[[101,103,105]]
# Out:
#                Name   ID Gender  Salary
# Employee_ID
# 101           Rahul  201   Male   50000
# 103          Vikram  203   Male   60000
# 105           Arjun  205   Male   58000

# %%
df1.iloc[0]
# Out:
# Name      Rahul
# ID          201
# Gender     Male
# Salary    50000
# Name: 101, dtype: object

# %%
df1.iloc[[0,3,4]]
# Out:
#               Name   ID  Gender  Salary
# Employee_ID
# 101          Rahul  201    Male   50000
# 104          Sneha  204  Female   52000
# 105          Arjun  205    Male   58000

# %% [markdown]
# **Accessing Specific Values**

# %%
df1
# Out:
#                Name   ID  Gender  Salary
# Employee_ID
# 101           Rahul  201    Male   50000
# 102           Anita  202  Female   55000
# 103          Vikram  203    Male   60000
# 104           Sneha  204  Female   52000
# 105           Arjun  205    Male   58000
# 106           Priya  206  Female   61000
# 107           Karan  207    Male   53000
# 108           Meera  208  Female   59000
# 109           Rohit  209    Male   62000
# 110           Divya  210  Female   54000
# 111            Aman  211    Male   57000
# 112            Neha  212  Female   63000

# %%
print(df1.loc[101],end='\n \n')
print(df1.loc[101]['Salary'])
# Out:
# Name      Rahul
# ID          201
# Gender     Male
# Salary    50000
# Name: 101, dtype: object
#
# 50000

# %%
print(df1.iloc[0]['Salary'])
print(df1.iloc[3]['Salary'])
# Out:
# 50000
# 52000

# %%
print(df1['Salary'][101] , end='\n \n')
print(df1['ID'][101])
# Out:
# 50000
#
# 201

# %%
print(df1.Name[108],end='\n \n')
print(df1.Salary[108])
# Out:
# Meera
#
# 59000

# %%
df1.loc[[101,104,108]]['Salary']
# Out:
# Employee_ID
# 101    50000
# 104    52000
# 108    59000
# Name: Salary, dtype: int64

# %%
df1.loc[[101,104,108]][['Salary','Name']]
# Out:
#              Salary   Name
# Employee_ID
# 101           50000  Rahul
# 104           52000  Sneha
# 108           59000  Meera

# %%
print(df1.loc[104,'Salary'],end='\n \n')
print(df1.loc[104,['Salary','ID']],end='\n \n')
print(df1.loc[[104,102,101],['Salary','ID']],end='\n \n')
print(df1.loc[102:106],end='\n \n')
print(df1.loc[102:106],['Salary','ID'],end='\n \n')
print(df1.loc[101:109,['Salary','ID']])
# Out:
# 52000
#
# Salary    52000
# ID          204
# Name: 104, dtype: object
#
#              Salary   ID
# Employee_ID
# 104           52000  204
# 102           55000  202
# 101           50000  201
#
#                Name   ID  Gender  Salary
# Employee_ID
# 102           Anita  202  Female   55000
# 103          Vikram  203    Male   60000
# 104           Sneha  204  Female   52000
# 105           Arjun  205    Male   58000
# 106           Priya  206  Female   61000
#
#                Name   ID  Gender  Salary
# Employee_ID
# 102           Anita  202  Female   55000
# 103          Vikram  203    Male   60000
# 104           Sneha  204  Female   52000
# 105           Arjun  205    Male   58000
# 106           Priya  206  Female   61000 ['Salary', 'ID']
#
#              Salary   ID
# Employee_ID
# 101           50000  201
# 102           55000  202
# 103           60000  203
# 104           52000  204
# 105           58000  205
# 106           61000  206
# 107           53000  207
# ...

# %%
df1.iloc[[1,2,3]][['Salary','ID']]
# Out:
#              Salary   ID
# Employee_ID
# 102           55000  202
# 103           60000  203
# 104           52000  204

# %%
print(df1.iloc[2]['Name'],end='\n \n')
print(df1.iloc[[0,2,3]][['Name','Salary']],end='\n \n')
# Out:
# Vikram
#
#                Name  Salary
# Employee_ID
# 101           Rahul   50000
# 103          Vikram   60000
# 104           Sneha   52000

# %%
print(df1['Name'],end='\n \n')
print(df1.loc[101],end='\n \n')
print(df1.loc[101,'Salary'])
# Out:
# Employee_ID
# 101     Rahul
# 102     Anita
# 103    Vikram
# 104     Sneha
# 105     Arjun
# 106     Priya
# 107     Karan
# 108     Meera
# 109     Rohit
# 110     Divya
# 111      Aman
# 112      Neha
# Name: Name, dtype: object
#
# Name      Rahul
# ID          201
# Gender     Male
# Salary    50000
# Name: 101, dtype: object
#
# 50000

# %% [markdown]
# **Adding and Deleting Rows and Columns**

# %%
df1
# Out:
#                Name   ID  Gender  Salary
# Employee_ID
# 101           Rahul  201    Male   50000
# 102           Anita  202  Female   55000
# 103          Vikram  203    Male   60000
# 104           Sneha  204  Female   52000
# 105           Arjun  205    Male   58000
# 106           Priya  206  Female   61000
# 107           Karan  207    Male   53000
# 108           Meera  208  Female   59000
# 109           Rohit  209    Male   62000
# 110           Divya  210  Female   54000
# 111            Aman  211    Male   57000
# 112            Neha  212  Female   63000

# %%
#Add Row
df1.loc[113]=["prithi",213,'Female',71000]

# %%
df1
# Out:
#                Name   ID  Gender  Salary
# Employee_ID
# 101           Rahul  201    Male   50000
# 102           Anita  202  Female   55000
# 103          Vikram  203    Male   60000
# 104           Sneha  204  Female   52000
# 105           Arjun  205    Male   58000
# 106           Priya  206  Female   61000
# 107           Karan  207    Male   53000
# 108           Meera  208  Female   59000
# 109           Rohit  209    Male   62000
# 110           Divya  210  Female   54000
# 111            Aman  211    Male   57000
# 112            Neha  212  Female   63000
# 113          prithi  213  Female   71000

# %%
#add column
import numpy as np
df1['Age']=np.random.randint(21,30,13)

# %%
df1
# Out:
#                Name   ID  Gender  Salary  Age
# Employee_ID
# 101           Rahul  201    Male   50000   23
# 102           Anita  202  Female   55000   26
# 103          Vikram  203    Male   60000   27
# 104           Sneha  204  Female   52000   22
# 105           Arjun  205    Male   58000   29
# 106           Priya  206  Female   61000   26
# 107           Karan  207    Male   53000   22
# 108           Meera  208  Female   59000   28
# 109           Rohit  209    Male   62000   28
# 110           Divya  210  Female   54000   25
# 111            Aman  211    Male   57000   28
# 112            Neha  212  Female   63000   23
# 113          prithi  213  Female   71000   27

# %%
#delete Row
df1.drop(113,inplace=True,axis=0)
df1
# Out:
#                Name   ID  Gender  Salary  Age
# Employee_ID
# 101           Rahul  201    Male   50000   23
# 102           Anita  202  Female   55000   26
# 103          Vikram  203    Male   60000   27
# 104           Sneha  204  Female   52000   22
# 105           Arjun  205    Male   58000   29
# 106           Priya  206  Female   61000   26
# 107           Karan  207    Male   53000   22
# 108           Meera  208  Female   59000   28
# 109           Rohit  209    Male   62000   28
# 110           Divya  210  Female   54000   25
# 111            Aman  211    Male   57000   28
# 112            Neha  212  Female   63000   23

# %%
#delete Column
df1['City']="Hyd"
#df1["city"]=['Hyd','Vij'] gives Length mismatch error
df1
# Out:
#                Name   ID  Gender  Salary  Age City
# Employee_ID
# 101           Rahul  201    Male   50000   23  Hyd
# 102           Anita  202  Female   55000   26  Hyd
# 103          Vikram  203    Male   60000   27  Hyd
# 104           Sneha  204  Female   52000   22  Hyd
# 105           Arjun  205    Male   58000   29  Hyd
# 106           Priya  206  Female   61000   26  Hyd
# 107           Karan  207    Male   53000   22  Hyd
# 108           Meera  208  Female   59000   28  Hyd
# 109           Rohit  209    Male   62000   28  Hyd
# 110           Divya  210  Female   54000   25  Hyd
# 111            Aman  211    Male   57000   28  Hyd
# 112            Neha  212  Female   63000   23  Hyd

# %%
df1.drop('City',inplace=True,axis=1)
df1
# Out:
#                Name   ID  Gender  Salary  Age
# Employee_ID
# 101           Rahul  201    Male   50000   23
# 102           Anita  202  Female   55000   26
# 103          Vikram  203    Male   60000   27
# 104           Sneha  204  Female   52000   22
# 105           Arjun  205    Male   58000   29
# 106           Priya  206  Female   61000   26
# 107           Karan  207    Male   53000   22
# 108           Meera  208  Female   59000   28
# 109           Rohit  209    Male   62000   28
# 110           Divya  210  Female   54000   25
# 111            Aman  211    Male   57000   28
# 112            Neha  212  Female   63000   23

# %%
#update Row
df1['Salary'][101]=100000
#update multipule rows at same time
df1.loc[[101,103],'Salary']=[200000,50000]
df1
# Out:
#                Name   ID  Gender  Salary  Age
# Employee_ID
# 101           Rahul  201    Male  200000   23
# 102           Anita  202  Female   55000   26
# 103          Vikram  203    Male   50000   27
# 104           Sneha  204  Female   52000   22
# 105           Arjun  205    Male   58000   29
# 106           Priya  206  Female   61000   26
# 107           Karan  207    Male   53000   22
# 108           Meera  208  Female   59000   28
# 109           Rohit  209    Male   62000   28
# 110           Divya  210  Female   54000   25
# 111            Aman  211    Male   57000   28
# 112            Neha  212  Female   63000   23

# %%
df1['Age']=1
df1
# Out:
#                Name   ID  Gender  Salary  Age
# Employee_ID
# 101           Rahul  201    Male  200000    1
# 102           Anita  202  Female   55000    1
# 103          Vikram  203    Male   50000    1
# 104           Sneha  204  Female   52000    1
# 105           Arjun  205    Male   58000    1
# 106           Priya  206  Female   61000    1
# 107           Karan  207    Male   53000    1
# 108           Meera  208  Female   59000    1
# 109           Rohit  209    Male   62000    1
# 110           Divya  210  Female   54000    1
# 111            Aman  211    Male   57000    1
# 112            Neha  212  Female   63000    1

# %%
df1['Age']=np.random.randint(22,30,12)

# %% [markdown]
# **Quering Based on Condition**

# %%
df1
# Out:
#                Name   ID  Gender  Salary  Age
# Employee_ID
# 101           Rahul  201    Male  200000   22
# 102           Anita  202  Female   55000   29
# 103          Vikram  203    Male   50000   23
# 104           Sneha  204  Female   52000   24
# 105           Arjun  205    Male   58000   24
# 106           Priya  206  Female   61000   29
# 107           Karan  207    Male   53000   28
# 108           Meera  208  Female   59000   23
# 109           Rohit  209    Male   62000   28
# 110           Divya  210  Female   54000   25
# 111            Aman  211    Male   57000   24
# 112            Neha  212  Female   63000   28

# %%
df1.Age>40
# Out:
# Employee_ID
# 101    False
# 102    False
# 103    False
# 104    False
# 105    False
# 106    False
# 107    False
# 108    False
# 109    False
# 110    False
# 111    False
# 112    False
# Name: Age, dtype: bool

# %%
df1[df1.Age>25]
# Out:
#               Name   ID  Gender  Salary  Age
# Employee_ID
# 102          Anita  202  Female   55000   29
# 106          Priya  206  Female   61000   29
# 107          Karan  207    Male   53000   28
# 109          Rohit  209    Male   62000   28
# 112           Neha  212  Female   63000   28

# %%
df1[df1.Age>25][['Age','Name','Salary']]
# Out:
#              Age   Name  Salary
# Employee_ID
# 102           29  Anita   55000
# 106           29  Priya   61000
# 107           28  Karan   53000
# 109           28  Rohit   62000
# 112           28   Neha   63000

# %%
df1[df1.Salary>50000][['Name','Salary']]
# Out:
#               Name  Salary
# Employee_ID
# 101          Rahul  200000
# 102          Anita   55000
# 104          Sneha   52000
# 105          Arjun   58000
# 106          Priya   61000
# 107          Karan   53000
# 108          Meera   59000
# 109          Rohit   62000
# 110          Divya   54000
# 111           Aman   57000
# 112           Neha   63000

# %%
df1[df1.Gender=="Male"]
# Out:
#                Name   ID Gender  Salary  Age
# Employee_ID
# 101           Rahul  201   Male  200000   22
# 103          Vikram  203   Male   50000   23
# 105           Arjun  205   Male   58000   24
# 107           Karan  207   Male   53000   28
# 109           Rohit  209   Male   62000   28
# 111            Aman  211   Male   57000   24

# %%
df1[df1.Gender=="Male"][df1.Salary>=60000]
# Out:
#               Name   ID Gender  Salary  Age
# Employee_ID
# 101          Rahul  201   Male  200000   22
# 109          Rohit  209   Male   62000   28

# %%
df1[df1.Gender=="Female"][df1.Salary<=60000]
# Out:
#               Name   ID  Gender  Salary  Age
# Employee_ID
# 102          Anita  202  Female   55000   29
# 104          Sneha  204  Female   52000   24
# 108          Meera  208  Female   59000   23
# 110          Divya  210  Female   54000   25

# %%
df1[(df1.Gender=='Male')&(df1.Salary>=60000)]
# Out:
#               Name   ID Gender  Salary  Age
# Employee_ID
# 101          Rahul  201   Male  200000   22
# 109          Rohit  209   Male   62000   28

# %%
df1[(df1.Gender=='Male')| (df1.Salary>=60000)]
# Out:
#                Name   ID  Gender  Salary  Age
# Employee_ID
# 101           Rahul  201    Male  200000   22
# 103          Vikram  203    Male   50000   23
# 105           Arjun  205    Male   58000   24
# 106           Priya  206  Female   61000   29
# 107           Karan  207    Male   53000   28
# 109           Rohit  209    Male   62000   28
# 111            Aman  211    Male   57000   24
# 112            Neha  212  Female   63000   28

# %%
df1[df1.Gender=="Male"][df1.Salary>=60000][df1.Salary<100000][df1.Age<40] # we can gove unlimited Conditions
# Out:
#               Name   ID Gender  Salary  Age
# Employee_ID
# 109          Rohit  209   Male   62000   28

# %%
df1[df1.Gender=="Male"][df1.Salary>=60000][df1.Salary<100000][df1.Age<40][['Name','Gender','Salary']]
# Out:
#               Name Gender  Salary
# Employee_ID
# 109          Rohit   Male   62000

# %% [markdown]
# **Query Fuction**

# %%
df1.query('Salary>10000 and Age<40')
# Out:
#                Name   ID  Gender  Salary  Age
# Employee_ID
# 101           Rahul  201    Male  200000   22
# 102           Anita  202  Female   55000   29
# 103          Vikram  203    Male   50000   23
# 104           Sneha  204  Female   52000   24
# 105           Arjun  205    Male   58000   24
# 106           Priya  206  Female   61000   29
# 107           Karan  207    Male   53000   28
# 108           Meera  208  Female   59000   23
# 109           Rohit  209    Male   62000   28
# 110           Divya  210  Female   54000   25
# 111            Aman  211    Male   57000   24
# 112            Neha  212  Female   63000   28

# %%
df1.query('Gender=="Female" or Salary>50000')
# Out:
#               Name   ID  Gender  Salary  Age
# Employee_ID
# 101          Rahul  201    Male  200000   22
# 102          Anita  202  Female   55000   29
# 104          Sneha  204  Female   52000   24
# 105          Arjun  205    Male   58000   24
# 106          Priya  206  Female   61000   29
# 107          Karan  207    Male   53000   28
# 108          Meera  208  Female   59000   23
# 109          Rohit  209    Male   62000   28
# 110          Divya  210  Female   54000   25
# 111           Aman  211    Male   57000   24
# 112           Neha  212  Female   63000   28

# %%
df1.query('Gender=="Female" or Salary>50000')[['Name','Age']]
# Out:
#               Name  Age
# Employee_ID
# 101          Rahul   22
# 102          Anita   29
# 104          Sneha   24
# 105          Arjun   24
# 106          Priya   29
# 107          Karan   28
# 108          Meera   23
# 109          Rohit   28
# 110          Divya   25
# 111           Aman   24
# 112           Neha   28

# %%
df1[df1.Salary>df1.Salary.mean()]
# Out:
#               Name   ID Gender  Salary  Age
# Employee_ID
# 101          Rahul  201   Male  200000   22

# %%
df1.query('Salary >' + str(df1.Salary.mean()))
# Out:
#               Name   ID Gender  Salary  Age
# Employee_ID
# 101          Rahul  201   Male  200000   22

# %% [markdown]
# **Important Functions**

# %%
df1.loc[113]=df1.loc[104]
df1.loc[114]=df1.loc[105]
df1.loc[115]=['Kaviya',215,'Female',np.nan,np.nan]
df1.loc[116]=['Rehan',216,"Male",180000,20]
df1.loc[117]=['Mohan',217,"Male",np.nan,np.nan]
df1
# Out:
#                Name   ID  Gender    Salary   Age
# Employee_ID
# 101           Rahul  201    Male  200000.0  22.0
# 102           Anita  202  Female   55000.0  29.0
# 103          Vikram  203    Male   50000.0  23.0
# 104           Sneha  204  Female   52000.0  24.0
# 105           Arjun  205    Male   58000.0  24.0
# 106           Priya  206  Female   61000.0  29.0
# 107           Karan  207    Male   53000.0  28.0
# 108           Meera  208  Female   59000.0  23.0
# 109           Rohit  209    Male   62000.0  28.0
# 110           Divya  210  Female   54000.0  25.0
# 111            Aman  211    Male   57000.0  24.0
# 112            Neha  212  Female   63000.0  28.0
# 113           Sneha  204  Female   52000.0  24.0
# 114           Arjun  205    Male   58000.0  24.0
# 115          Kaviya  215  Female       NaN   NaN
# 116           Rehan  216    Male  180000.0  20.0
# 117           Mohan  217    Male       NaN   NaN

# %%
df1.head()
# Out:
#                Name   ID  Gender    Salary   Age
# Employee_ID
# 101           Rahul  201    Male  200000.0  22.0
# 102           Anita  202  Female   55000.0  29.0
# 103          Vikram  203    Male   50000.0  23.0
# 104           Sneha  204  Female   52000.0  24.0
# 105           Arjun  205    Male   58000.0  24.0

# %%
df1.head(3)
# Out:
#                Name   ID  Gender    Salary   Age
# Employee_ID
# 101           Rahul  201    Male  200000.0  22.0
# 102           Anita  202  Female   55000.0  29.0
# 103          Vikram  203    Male   50000.0  23.0

# %%
df1.tail()
# Out:
#                Name   ID  Gender    Salary   Age
# Employee_ID
# 113           Sneha  204  Female   52000.0  24.0
# 114           Arjun  205    Male   58000.0  24.0
# 115          Kaviya  215  Female       NaN   NaN
# 116           Rehan  216    Male  180000.0  20.0
# 117           Mohan  217    Male       NaN   NaN

# %%
df1.tail(2)
# Out:
#               Name   ID Gender    Salary   Age
# Employee_ID
# 116          Rehan  216   Male  180000.0  20.0
# 117          Mohan  217   Male       NaN   NaN

# %%
df1.isnull().sum()
# Out:
# Name      0
# ID        0
# Gender    0
# Salary    2
# Age       2
# dtype: int64

# %%
df1.Salary.isnull().sum()
# Out:
# np.int64(2)

# %%
df1.notnull().sum()
# Out:
# Name      17
# ID        17
# Gender    17
# Salary    15
# Age       15
# dtype: int64

# %%
df1.isna()
# Out:
#               Name     ID  Gender  Salary    Age
# Employee_ID
# 101          False  False   False   False  False
# 102          False  False   False   False  False
# 103          False  False   False   False  False
# 104          False  False   False   False  False
# 105          False  False   False   False  False
# 106          False  False   False   False  False
# 107          False  False   False   False  False
# 108          False  False   False   False  False
# 109          False  False   False   False  False
# 110          False  False   False   False  False
# 111          False  False   False   False  False
# 112          False  False   False   False  False
# 113          False  False   False   False  False
# 114          False  False   False   False  False
# 115          False  False   False    True   True
# 116          False  False   False   False  False
# 117          False  False   False    True   True

# %%
df1.isna().sum()
# Out:
# Name      0
# ID        0
# Gender    0
# Salary    2
# Age       2
# dtype: int64

# %%
df1.isnull()
# Out:
#               Name     ID  Gender  Salary    Age
# Employee_ID
# 101          False  False   False   False  False
# 102          False  False   False   False  False
# 103          False  False   False   False  False
# 104          False  False   False   False  False
# 105          False  False   False   False  False
# 106          False  False   False   False  False
# 107          False  False   False   False  False
# 108          False  False   False   False  False
# 109          False  False   False   False  False
# 110          False  False   False   False  False
# 111          False  False   False   False  False
# 112          False  False   False   False  False
# 113          False  False   False   False  False
# 114          False  False   False   False  False
# 115          False  False   False    True   True
# 116          False  False   False   False  False
# 117          False  False   False    True   True

# %%
df1.duplicated()
# Out:
# Employee_ID
# 101    False
# 102    False
# 103    False
# 104    False
# 105    False
# 106    False
# 107    False
# 108    False
# 109    False
# 110    False
# 111    False
# 112    False
# 113     True
# 114     True
# 115    False
# 116    False
# 117    False
# dtype: bool

# %%
df1.duplicated().sum()
# Out:
# np.int64(2)

# %%
df1.drop_duplicates(inplace=True)
df1
# Out:
#                Name   ID  Gender    Salary   Age
# Employee_ID
# 101           Rahul  201    Male  200000.0  22.0
# 102           Anita  202  Female   55000.0  29.0
# 103          Vikram  203    Male   50000.0  23.0
# 104           Sneha  204  Female   52000.0  24.0
# 105           Arjun  205    Male   58000.0  24.0
# 106           Priya  206  Female   61000.0  29.0
# 107           Karan  207    Male   53000.0  28.0
# 108           Meera  208  Female   59000.0  23.0
# 109           Rohit  209    Male   62000.0  28.0
# 110           Divya  210  Female   54000.0  25.0
# 111            Aman  211    Male   57000.0  24.0
# 112            Neha  212  Female   63000.0  28.0
# 115          Kaviya  215  Female       NaN   NaN
# 116           Rehan  216    Male  180000.0  20.0
# 117           Mohan  217    Male       NaN   NaN

# %%
df1.nunique()
# Out:
# Name      15
# ID        15
# Gender     2
# Salary    13
# Age        7
# dtype: int64

# %%
df1['Salary'].nunique()
# Out:
# 13

# %%
df1['Salary'].unique()
# Out:
# array([200000.,  55000.,  50000.,  52000.,  58000.,  61000.,  53000.,
#         59000.,  62000.,  54000.,  57000.,  63000.,     nan, 180000.])

# %%
df1['Gender'].dropna().unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df1.sort_index()
# Out:
#                Name   ID  Gender    Salary   Age
# Employee_ID
# 101           Rahul  201    Male  200000.0  22.0
# 102           Anita  202  Female   55000.0  29.0
# 103          Vikram  203    Male   50000.0  23.0
# 104           Sneha  204  Female   52000.0  24.0
# 105           Arjun  205    Male   58000.0  24.0
# 106           Priya  206  Female   61000.0  29.0
# 107           Karan  207    Male   53000.0  28.0
# 108           Meera  208  Female   59000.0  23.0
# 109           Rohit  209    Male   62000.0  28.0
# 110           Divya  210  Female   54000.0  25.0
# 111            Aman  211    Male   57000.0  24.0
# 112            Neha  212  Female   63000.0  28.0
# 115          Kaviya  215  Female       NaN   NaN
# 116           Rehan  216    Male  180000.0  20.0
# 117           Mohan  217    Male       NaN   NaN

# %%
df1.sort_index(ascending=False)
# Out:
#                Name   ID  Gender    Salary   Age
# Employee_ID
# 117           Mohan  217    Male       NaN   NaN
# 116           Rehan  216    Male  180000.0  20.0
# 115          Kaviya  215  Female       NaN   NaN
# 112            Neha  212  Female   63000.0  28.0
# 111            Aman  211    Male   57000.0  24.0
# 110           Divya  210  Female   54000.0  25.0
# 109           Rohit  209    Male   62000.0  28.0
# 108           Meera  208  Female   59000.0  23.0
# 107           Karan  207    Male   53000.0  28.0
# 106           Priya  206  Female   61000.0  29.0
# 105           Arjun  205    Male   58000.0  24.0
# 104           Sneha  204  Female   52000.0  24.0
# 103          Vikram  203    Male   50000.0  23.0
# 102           Anita  202  Female   55000.0  29.0
# 101           Rahul  201    Male  200000.0  22.0

# %%
df1.sort_values(by='Salary')
# Out:
#                Name   ID  Gender    Salary   Age
# Employee_ID
# 103          Vikram  203    Male   50000.0  23.0
# 104           Sneha  204  Female   52000.0  24.0
# 107           Karan  207    Male   53000.0  28.0
# 110           Divya  210  Female   54000.0  25.0
# 102           Anita  202  Female   55000.0  29.0
# 111            Aman  211    Male   57000.0  24.0
# 105           Arjun  205    Male   58000.0  24.0
# 108           Meera  208  Female   59000.0  23.0
# 106           Priya  206  Female   61000.0  29.0
# 109           Rohit  209    Male   62000.0  28.0
# 112            Neha  212  Female   63000.0  28.0
# 116           Rehan  216    Male  180000.0  20.0
# 101           Rahul  201    Male  200000.0  22.0
# 115          Kaviya  215  Female       NaN   NaN
# 117           Mohan  217    Male       NaN   NaN

# %%
df1.sort_values(by='Salary',ascending=False)
# Out:
#                Name   ID  Gender    Salary   Age
# Employee_ID
# 101           Rahul  201    Male  200000.0  22.0
# 116           Rehan  216    Male  180000.0  20.0
# 112            Neha  212  Female   63000.0  28.0
# 109           Rohit  209    Male   62000.0  28.0
# 106           Priya  206  Female   61000.0  29.0
# 108           Meera  208  Female   59000.0  23.0
# 105           Arjun  205    Male   58000.0  24.0
# 111            Aman  211    Male   57000.0  24.0
# 102           Anita  202  Female   55000.0  29.0
# 110           Divya  210  Female   54000.0  25.0
# 107           Karan  207    Male   53000.0  28.0
# 104           Sneha  204  Female   52000.0  24.0
# 103          Vikram  203    Male   50000.0  23.0
# 115          Kaviya  215  Female       NaN   NaN
# 117           Mohan  217    Male       NaN   NaN

# %%
df1.sort_values(by=['Age','Salary'])
# Out:
#                Name   ID  Gender    Salary   Age
# Employee_ID
# 116           Rehan  216    Male  180000.0  20.0
# 101           Rahul  201    Male  200000.0  22.0
# 103          Vikram  203    Male   50000.0  23.0
# 108           Meera  208  Female   59000.0  23.0
# 104           Sneha  204  Female   52000.0  24.0
# 111            Aman  211    Male   57000.0  24.0
# 105           Arjun  205    Male   58000.0  24.0
# 110           Divya  210  Female   54000.0  25.0
# 107           Karan  207    Male   53000.0  28.0
# 109           Rohit  209    Male   62000.0  28.0
# 112            Neha  212  Female   63000.0  28.0
# 102           Anita  202  Female   55000.0  29.0
# 106           Priya  206  Female   61000.0  29.0
# 115          Kaviya  215  Female       NaN   NaN
# 117           Mohan  217    Male       NaN   NaN

# %%
pd.concat([df1,df1],axis=0)
# Out:
#                Name   ID  Gender    Salary   Age
# Employee_ID
# 101           Rahul  201    Male  200000.0  22.0
# 102           Anita  202  Female   55000.0  29.0
# 103          Vikram  203    Male   50000.0  23.0
# 104           Sneha  204  Female   52000.0  24.0
# 105           Arjun  205    Male   58000.0  24.0
# 106           Priya  206  Female   61000.0  29.0
# 107           Karan  207    Male   53000.0  28.0
# 108           Meera  208  Female   59000.0  23.0
# 109           Rohit  209    Male   62000.0  28.0
# 110           Divya  210  Female   54000.0  25.0
# 111            Aman  211    Male   57000.0  24.0
# 112            Neha  212  Female   63000.0  28.0
# 115          Kaviya  215  Female       NaN   NaN
# 116           Rehan  216    Male  180000.0  20.0
# 117           Mohan  217    Male       NaN   NaN
# 101           Rahul  201    Male  200000.0  22.0
# 102           Anita  202  Female   55000.0  29.0
# 103          Vikram  203    Male   50000.0  23.0
# ...

# %%
pd.concat([df1,df1],axis=1)
# Out:
#                Name   ID  Gender    Salary   Age    Name   ID  Gender  \
# Employee_ID
# 101           Rahul  201    Male  200000.0  22.0   Rahul  201    Male
# 102           Anita  202  Female   55000.0  29.0   Anita  202  Female
# 103          Vikram  203    Male   50000.0  23.0  Vikram  203    Male
# 104           Sneha  204  Female   52000.0  24.0   Sneha  204  Female
# 105           Arjun  205    Male   58000.0  24.0   Arjun  205    Male
# 106           Priya  206  Female   61000.0  29.0   Priya  206  Female
# 107           Karan  207    Male   53000.0  28.0   Karan  207    Male
# 108           Meera  208  Female   59000.0  23.0   Meera  208  Female
# 109           Rohit  209    Male   62000.0  28.0   Rohit  209    Male
# 110           Divya  210  Female   54000.0  25.0   Divya  210  Female
# 111            Aman  211    Male   57000.0  24.0    Aman  211    Male
# 112            Neha  212  Female   63000.0  28.0    Neha  212  Female
# ...

# %%
df1.Salary.value_counts()
# Out:
# Salary
# 200000.0    1
# 55000.0     1
# 50000.0     1
# 52000.0     1
# 58000.0     1
# 61000.0     1
# 53000.0     1
# 59000.0     1
# 62000.0     1
# 54000.0     1
# 57000.0     1
# 63000.0     1
# 180000.0    1
# Name: count, dtype: int64

# %%
df1.Gender.value_counts()
# Out:
# Gender
# Male      8
# Female    7
# Name: count, dtype: int64

# %%
df1.Gender.value_counts(normalize=True) # ratio of distribution
# Out:
# Gender
# Male      0.533333
# Female    0.466667
# Name: proportion, dtype: float64

# %%
df1.describe()
# Out:
#                ID         Salary        Age
# count   15.000000      13.000000  13.000000
# mean   208.400000   77230.769231  25.153846
# std      5.082182   50367.241083   2.939562
# min    201.000000   50000.000000  20.000000
# 25%    204.500000   54000.000000  23.000000
# 50%    208.000000   58000.000000  24.000000
# 75%    211.500000   62000.000000  28.000000
# max    217.000000  200000.000000  29.000000

# %%
df1[['Age','Salary']].describe()
# Out:
#              Age         Salary
# count  13.000000      13.000000
# mean   25.153846   77230.769231
# std     2.939562   50367.241083
# min    20.000000   50000.000000
# 25%    23.000000   54000.000000
# 50%    24.000000   58000.000000
# 75%    28.000000   62000.000000
# max    29.000000  200000.000000

# %%
df1.count()
# Out:
# Name      15
# ID        15
# Gender    15
# Salary    13
# Age       13
# dtype: int64

# %%
df1.Salary.mean()
# Out:
# np.float64(77230.76923076923)

# %%
df1.Salary.var()
# Out:
# 2536858974.358975

# %%
df1.Salary.std()
# Out:
# 50367.24108345597

# %%
df1.Salary.median()
# Out:
# 58000.0

# %%
df1.Age.mode()
# Out:
# 0    24.0
# 1    28.0
# Name: Age, dtype: float64

# %%
df1.Age.value_counts()
# Out:
# Age
# 24.0    3
# 28.0    3
# 29.0    2
# 23.0    2
# 22.0    1
# 25.0    1
# 20.0    1
# Name: count, dtype: int64

# %%
df1.Age.quantile(0.25)
# Out:
# np.float64(23.0)

# %%
df1.Age.quantile(0.5)
# Out:
# np.float64(24.0)

# %%
df1.Age.quantile(0.75)
# Out:
# np.float64(28.0)

# %%
df1['Salary'].apply(np.sqrt)
# Out:
# Employee_ID
# 101    447.213595
# 102    234.520788
# 103    223.606798
# 104    228.035085
# 105    240.831892
# 106    246.981781
# 107    230.217289
# 108    242.899156
# 109    248.997992
# 110    232.379001
# 111    238.746728
# 112    250.998008
# 115           NaN
# 116    424.264069
# 117           NaN
# Name: Salary, dtype: float64

# %%
df1.Salary.apply(lambda num: 1.1* num)
# Out:
# Employee_ID
# 101    220000.0
# 102     60500.0
# 103     55000.0
# 104     57200.0
# 105     63800.0
# 106     67100.0
# 107     58300.0
# 108     64900.0
# 109     68200.0
# 110     59400.0
# 111     62700.0
# 112     69300.0
# 115         NaN
# 116    198000.0
# 117         NaN
# Name: Salary, dtype: float64

# %%
df1.groupby(by='Gender')['Age'].mean()
# Out:
# Gender
# Female    26.333333
# Male      24.142857
# Name: Age, dtype: float64

# %%
df1[['Salary','Age']].cov()
# Out:
#               Salary           Age
# Salary  2.536859e+09 -86788.461538
# Age    -8.678846e+04      8.641026

# %%
df1[['Salary','Age']].corr()
# Out:
#          Salary      Age
# Salary  1.00000 -0.58618
# Age    -0.58618  1.00000

# %% [markdown]
# **Dealing with csv files**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data=pd.read_csv("/content/drive/MyDrive/Contnet/Automobile_data.csv")

# %%
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
list(data.columns)
# Out:
# ['symboling',
#  'normalized-losses',
#  'make',
#  'fuel-type',
#  'aspiration',
#  'num-of-doors',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-type',
#  'num-of-cylinders',
#  'engine-size',
#  'fuel-system',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg',
#  'price']

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.shape
# Out:
# (205, 26)

# %%
data.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
data.replace('?',np.nan,inplace=True)

# %%
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
data.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
data['price']=data['price'].astype(float)
data['peak-rpm']=data['peak-rpm'].astype(float)
data['hoursepower']=data['horsepower'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
data.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2               NaN         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1               NaN         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0               NaN         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  fuel-system  \
# ...

# %%
data.nunique()
# Out:
# symboling              6
# normalized-losses     51
# make                  22
# fuel-type              2
# aspiration             2
# num-of-doors           2
# body-style             5
# drive-wheels           3
# engine-location        2
# wheel-base            53
# length                75
# width                 44
# height                49
# curb-weight          171
# engine-type            7
# num-of-cylinders       7
# engine-size           44
# fuel-system            8
# bore                  38
# stroke                36
# compression-ratio     32
# horsepower            59
# peak-rpm              23
# city-mpg              29
# highway-mpg           30
# price                186
# hoursepower           59
# dtype: int64

# %%
print('Fuel Types : ',data['fuel-type'].unique())
print('Body Styles : ',data['body-style'].unique())
print('Driver Wheels : ', data['body-style'].unique())
print('Fuel System : ',data['fuel-system'].unique())
print('Engine Type : ',data['engine-type'].unique())
# Out:
# Fuel Types :  ['gas' 'diesel']
# Body Styles :  ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# Driver Wheels :  ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# Fuel System :  ['mpfi' '2bbl' 'mfi' '1bbl' 'spfi' '4bbl' 'idi' 'spdi']
# Engine Type :  ['dohc' 'ohcv' 'ohc' 'l' 'rotor' 'ohcf' 'dohcv']

# %%
data['city-mpg'].mean()
# Out:
# np.float64(25.21951219512195)

# %%
data.groupby(by='fuel-type')['city-mpg'].mean()
# Out:
# fuel-type
# diesel    30.30000
# gas       24.67027
# Name: city-mpg, dtype: float64

# %%
data.groupby(by='body-style').value_counts()
# Out:
# body-style   symboling  normalized-losses  make           fuel-type  aspiration  num-of-doors  drive-wheels  engine-location  wheel-base  length  width  height  curb-weight  engine-type  num-of-cylinders  engine-size  fuel-system  bore  stroke  compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg  price    hoursepower
# convertible  2          134                toyota         gas        std         two           rwd           front            98.4        176.2   65.6   53.0    2975         ohc          four              146          mpfi         3.62  3.5     9.3                116         4800.0    24        30           17669.0  116.0          1
# ...

# %%
data['body-style'].value_counts()
# Out:
# body-style
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
data['fuel-type'].value_counts(normalize=True)
# Out:
# fuel-type
# gas       0.902439
# diesel    0.097561
# Name: proportion, dtype: float64

# %%
data.groupby(by='body-style')['highway-mpg'].mean()
# Out:
# body-style
# convertible    26.000000
# hardtop        27.250000
# hatchback      32.171429
# sedan          30.833333
# wagon          28.720000
# Name: highway-mpg, dtype: float64

# %%
data.groupby(by='body-style')['highway-mpg'].mean().sort_values(ascending=False)
# Out:
# body-style
# hatchback      32.171429
# sedan          30.833333
# wagon          28.720000
# hardtop        27.250000
# convertible    26.000000
# Name: highway-mpg, dtype: float64

# %%
data.groupby(by='aspiration')['highway-mpg'].mean().sort_values()
# Out:
# aspiration
# turbo    27.027027
# std      31.571429
# Name: highway-mpg, dtype: float64

# %%
data.groupby(by='aspiration')['city-mpg'].mean().sort_values(ascending=False)
# Out:
# aspiration
# std      25.839286
# turbo    22.405405
# Name: city-mpg, dtype: float64

# %%
data.groupby(by=['body-style','fuel-type'])['city-mpg'].mean()
# Out:
# body-style   fuel-type
# convertible  gas          20.500000
# hardtop      diesel       22.000000
#              gas          21.571429
# hatchback    diesel       38.000000
#              gas          26.144928
# sedan        diesel       31.600000
#              gas          24.160494
# wagon        diesel       24.000000
#              gas          24.045455
# Name: city-mpg, dtype: float64

# %%
data.groupby(by=['aspiration','fuel-type'])['city-mpg'].mean()
# Out:
# aspiration  fuel-type
# std         diesel       36.857143
#             gas          25.360248
# turbo       diesel       26.769231
#             gas          20.041667
# Name: city-mpg, dtype: float64

# %%
data.groupby(by=['fuel-type','aspiration'])['city-mpg'].mean()
# Out:
# fuel-type  aspiration
# diesel     std           36.857143
#            turbo         26.769231
# gas        std           25.360248
#            turbo         20.041667
# Name: city-mpg, dtype: float64

# %%
data['comb-mpg']=(data['city-mpg']+data['highway-mpg'])

# %%
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  bore  stroke  \
# 0  convertible          rwd           front        88.6  ...  3.47    2.68
# 1  convertible          rwd           front        88.6  ...  3.47    2.68
# 2    hatchback          rwd           front        94.5  ...  2.68    3.47
# 3        sedan          fwd           front        99.8  ...  3.19     3.4
# 4        sedan          4wd           front        99.4  ...  3.19     3.4
#
# ...
